# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn import tree #for DecisionTreeClassifier

df = pd.read_csv("actual_final_data.csv")
del df['Unnamed: 0']
df
# Out:
#         movieId    count  avg_rating                    director      genre  \
# 0      131072.0      1.0    2.500000          Florian David Fitz     Comedy
# 1           1.0  49695.0    3.921240               John Lasseter  Animation
# 2           2.0  22243.0    3.211977                Joe Johnston  Adventure
# 3           3.0  12735.0    3.151040               Howard Deutch     Comedy
# 4           4.0   2756.0    2.861393             Forest Whitaker     Comedy
# ...         ...      ...         ...                         ...        ...
# 25986  131060.0      1.0    1.500000                Tobi Baumann     Comedy
# 25987  131062.0      1.0    0.500000                  Jim Torres      Drama
# 25988  131066.0      1.0    3.000000  Kresten Vestbjerg Andersen  Animation
# 25989  131068.0      1.0    3.000000             Florian Gärtner     Comedy
# 25990  131070.0      1.0    2.500000                Alex Schmidt      Drama
#
#        year        LeadActor language
# 0      2012  Jessica Schwarz   German
# 1      1995        Tom Hanks  English
# 2      1995   Robin Williams  English
# 3      1995   Walter Matthau  English
# 4      1995  Whitney Houston  English
# ...     ...              ...      ...
# 25986  2007    Oliver Pocher   German
# 25987  2008   Joshua Leonard  English
# 25988  2011      Anders Juul   Danish
# 25989  2005   André Kaminski   German
# 25990  2012      Mina Tander   German
#
# [25991 rows x 8 columns]

# %% [markdown]
# # WHAT MUST BE DONE:
# 1) create X (all data except movieId and rating) and Y (rating only) dataframes <br>
# 2) encode X data (specifically director, LeadActor, genre, language) <br>
# 3) encode Y data, map to make binary (e.g. rating < 3.0 means 'bad (0)' and above means 'good (1)') <br>
# 4) split into testing and training <br>
# 5) fit decision tree to create models and make predictions, check accuracy <br>
# 6) check accuracy or whatever
